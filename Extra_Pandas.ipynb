# %%
pip list
# Out:
# Package                   Version
# ------------------------- --------------
# anyio                     4.10.0
# appnope                   0.1.4
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.3.0
# asttokens                 3.0.0
# async-lru                 2.0.5
# attrs                     25.3.0
# babel                     2.17.0
# beautifulsoup4            4.13.5
# bleach                    6.2.0
# certifi                   2025.8.3
# cffi                      1.17.1
# charset-normalizer        3.4.3
# comm                      0.2.3
# debugpy                   1.8.16
# decorator                 5.2.1
# defusedxml                0.7.1
# executing                 2.2.0
# fastjsonschema            2.21.2
# fqdn                      1.5.1
# h11                       0.16.0
# httpcore                  1.0.9
# httpx                     0.28.1
# idna                      3.10
# ipykernel                 6.30.1
# ...

# %%
# !pip3 install pandas

# %%
import pandas as pd

# %%
import os
os. getcwd()
# Out:
# '/Users/taherehehsan'

# %%
sal = pd.read_csv('/Users/taherehehsan/Salaries.csv')

# %%
sal
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
type(sal)
# Out:
# pandas.core.frame.DataFrame

# %%
sal.head(5)
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
sal.tail(2)
# Out:
#             Id  EmployeeName                    JobTitle  BasePay  \
# 148652  148653  Not provided                Not provided      NaN
# 148653  148654     Joe Lopez  Counselor, Log Cabin Ranch      0.0
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  \
# 148652          NaN       NaN       NaN      0.00              0.00  2014
# 148653          0.0   -618.13       0.0   -618.13           -618.13  2014
#
#         Notes         Agency  Status
# 148652    NaN  San Francisco     NaN
# 148653    NaN  San Francisco     NaN

# %%
sal.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
sal.shape
# Out:
# (148654, 13)

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
sal.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148654.000000  148045.000000  148650.000000  148650.000000
# mean    74327.500000   66325.448840    5066.059886    3648.767297
# std     42912.857795   42764.635495   11454.380559    8056.601866
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37164.250000   33588.200000       0.000000       0.000000
# 50%     74327.500000   65007.450000       0.000000     811.270000
# 75%    111490.750000   94691.050000    4658.175000    4236.065000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits       TotalPay  TotalPayBenefits           Year  Notes  \
# count  112491.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    25007.893151   74768.321972      93692.554811    2012.522643    NaN
# std     15402.215858   50517.005274      62793.533483       1.117538    NaN
# ...

# %%
sal['JobTitle']
# Out:
# 0         GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                        CAPTAIN III (POLICE DEPARTMENT)
# 2                        CAPTAIN III (POLICE DEPARTMENT)
# 3                   WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4           DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#                                ...
# 148649                                         Custodian
# 148650                                      Not provided
# 148651                                      Not provided
# 148652                                      Not provided
# 148653                        Counselor, Log Cabin Ranch
# Name: JobTitle, Length: 148654, dtype: object

# %%
sal['JobTitle'][3]
# Out:
# 'WIRE ROPE CABLE MAINTENANCE MECHANIC'

# %%
type(sal['JobTitle'])
# Out:
# pandas.core.series.Series

# %%
lst= list(sal['JobTitle'])

# %%
lst
# Out:
# ['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#  'CAPTAIN III (POLICE DEPARTMENT)',
#  'CAPTAIN III (POLICE DEPARTMENT)',
#  'WIRE ROPE CABLE MAINTENANCE MECHANIC',
#  'DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)',
#  'ASSISTANT DEPUTY CHIEF II',
#  'BATTALION CHIEF, (FIRE DEPARTMENT)',
#  'DEPUTY DIRECTOR OF INVESTMENTS',
#  'BATTALION CHIEF, (FIRE DEPARTMENT)',
#  'CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)',
#  'ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)',
#  'CAPTAIN III (POLICE DEPARTMENT)',
#  'EXECUTIVE CONTRACT EMPLOYEE',
#  'DEPARTMENT HEAD V',
#  'BATTALION CHIEF, (FIRE DEPARTMENT)',
#  'COMMANDER III, (POLICE DEPARTMENT)',
#  'DEPARTMENT HEAD V',
#  'CAPTAIN, EMERGENCYCY MEDICAL SERVICES',
#  'BATTALION CHIEF, (FIRE DEPARTMENT)',
#  'ASSISTANT MEDICAL EXAMINER',
#  'ASSISTANT MEDICAL EXAMINER',
#  'ASSISTANT MEDICAL EXAMINER',
#  'CAPTAIN, FIRE SUPPRESSION',
#  'BATTALION CHIEF, (FIRE DEPARTMENT)',
#  'CAPTAIN, FIRE SUPPRESSION',
#  'CHIEF OF POLICE',
# ...

# %%
new_lst= ['Permenant '+ item for item in lst]

# %%
new_lst
# Out:
# ['Permenant GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#  'Permenant CAPTAIN III (POLICE DEPARTMENT)',
#  'Permenant CAPTAIN III (POLICE DEPARTMENT)',
#  'Permenant WIRE ROPE CABLE MAINTENANCE MECHANIC',
#  'Permenant DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)',
#  'Permenant ASSISTANT DEPUTY CHIEF II',
#  'Permenant BATTALION CHIEF, (FIRE DEPARTMENT)',
#  'Permenant DEPUTY DIRECTOR OF INVESTMENTS',
#  'Permenant BATTALION CHIEF, (FIRE DEPARTMENT)',
#  'Permenant CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)',
#  'Permenant ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)',
#  'Permenant CAPTAIN III (POLICE DEPARTMENT)',
#  'Permenant EXECUTIVE CONTRACT EMPLOYEE',
#  'Permenant DEPARTMENT HEAD V',
#  'Permenant BATTALION CHIEF, (FIRE DEPARTMENT)',
#  'Permenant COMMANDER III, (POLICE DEPARTMENT)',
#  'Permenant DEPARTMENT HEAD V',
#  'Permenant CAPTAIN, EMERGENCYCY MEDICAL SERVICES',
#  'Permenant BATTALION CHIEF, (FIRE DEPARTMENT)',
#  'Permenant ASSISTANT MEDICAL EXAMINER',
# ...

# %%
## Extra - 01_ Exercises

7**4
# Out:
# 2401

# %%
s = "Hi there Sam!" 
s.split()
# Out:
# ['Hi', 'there', 'Sam!']

# %%
planet = "Earth"
diameter = 12742

# %%
print('The diameter of {} is {} kilometer.'. format(planet,diameter))
# Out:
# The diameter of Earth is 12742 kilometer.

# %%
lst = [1,2,[3,4],[5,[100,200,['hello']],23,11],1,7]

# %%
lst[3][1][2]
# Out:
# ['hello']

# %%
d = {'k1':[1,2,3,{'tricky':['oh','man','inception',{'target':[1,2,3,'hello']}]}]}

# %%
d['k1'][3]['tricky'][3]['target'][3]
# Out:
# 'hello'

# %%
# Create a function that grabs the email website domain from a string in the form:
# user@domain.com

email= 'user@domain.com'
email.split()
# Out:
# ['user@domain.com']

# %%
email.split('@')
# Out:
# ['user', 'domain.com']

# %%
email.split('@')[-1]
# Out:
# 'domain.com'

# %%
email= 'user@domain.com'

def domainget(email):
    return email.split('@')[-1]

# %%
domainget(email)
# Out:
# 'domain.com'

# %%
## Create a basic function that returns True if the word 'dog' is contained in the input string
## Don't worry about edge cases like a punctuation being attached to the word dog,
## but do account for capitalization.

st = 'Is there a dog here?'

def finddog(st):
    return 'dog' in st

# %%
finddog(st)
# Out:
# True

# %%
## or 

def finddog(st):
    return 'dog' in st.lower().split()

# %%
finddog(st)
# Out:
# True

# %%
## Create a function that counts the number of times the word "dog" occurs in a string. 
## Again ignore edge cases.

str_1 = 'This dog runs faster than the other dog dude!'

def countdog(str_1):
    count = 0
    for word in str_1.lower().split():
        if word == 'dog':
            count +=1
    return count

# %%
countdog(str_1)
# Out:
# 2

# %%
## Use lambda expressions and the filter() function to filter out words from a list 
## that don't start with the letter 's'. For example:

seq = ['soup','dog','salad','cat','great']

# should be filtered down to:

['soup','salad']

# %%
seq = ['soup','dog','salad','cat','great']
list(filter(lambda word: word[0]== 's', seq))
# Out:
# ['soup', 'salad']

# %%
# You are driving a little too fast, and a police officer stops you. 
# Write a function to return one of 3 possible results: 
# "No ticket", "Small ticket", or "Big Ticket". 
# If your speed is 60 or less, the result is "No Ticket". 
# If speed is between 61 and 80 inclusive, the result is "Small Ticket".
# If speed is 81 or more, the result is "Big Ticket". 
# Unless it is your birthday (encoded as a boolean value in the parameters of the function) 
# on your birthday, your speed can be 5 higher in all cases. 


def  caught_speeding(speed, is_birthday):
    if is_birthday:
        speeding = speed - 5
    else:
        speeding = speed

    if speeding > 80:
        return 'Big Ticket'
    elif speeding > 60:
        return 'Small Ticket'
    else :
        return 'No Ticket'

# %%
caught_speeding(81, True)
# Out:
# 'Small Ticket'

# %%
caught_speeding(81,False)
# Out:
# 'Big Ticket'

# %%
def cinema_ticket_pricing(price , is_summer):
    
    if is_summer:
        pricing = price - 2
    else:
        pricing = price

    if pricing >20:
        return '15$'
    elif pricing > 10:
        return '10$'
    else:
        return '5$'

# %%
cinema_ticket_pricing(22, True)
# Out:
# '10$'

# %%
cinematicketprice(22, False)
# Out:
# '15$'

# %%
## Extra_2 


import pandas as pd

# %%
import os
os.getcwd()
# Out:
# '/Users/taherehehsan'

# %%
# Read Salaries.csv as a dataframe called sal.

sal = pd.read_csv('/Users/taherehehsan/Salaries.csv')

# %%
sal
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
## Check the head of the DataFrame.##

sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
## Use the .info() method to find out how many entries there are.##

sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
## What is the average BasePay ?##

sal['BasePay'].mean()
# Out:
# np.float64(66325.44884048769)

# %%
## What is the highest amount of OvertimePay in the dataset ?## 

sal['OvertimePay'].max()
# Out:
# np.float64(245131.88)

# %%
## What is the job title of JOSEPH DRISCOLL ?
# Note: Use all caps, otherwise you may get an answer that doesn't match up 
# (there is also a lowercase Joseph Driscoll). 

sal[sal['EmployeeName']== 'JOSEPH DRISCOLL']['JobTitle']
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %%
## How much does JOSEPH DRISCOLL make (including benefits)? ##

sal[sal['EmployeeName'] == 'JOSEPH DRISCOLL']['TotalPayBenefits']
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %%
## What is the name of highest paid person (including benefits)?##

sal[sal['TotalPayBenefits']== sal['TotalPayBenefits'].max()]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN

# %%
## What is the name of highest paid person (including benefits)?

sal[sal['TotalPayBenefits']== sal['TotalPayBenefits'].max()]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN

# %%
## What is the name of lowest paid person (including benefits)?
## Do you notice something strange about how much he or she is paid?

sal[sal['TotalPayBenefits'] == sal['TotalPayBenefits'].min()]

# It is negative!! strange!
# Out:
#             Id EmployeeName                    JobTitle  BasePay  OvertimePay  \
# 148653  148654    Joe Lopez  Counselor, Log Cabin Ranch      0.0          0.0
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148653   -618.13       0.0   -618.13           -618.13  2014    NaN
#
#                Agency  Status
# 148653  San Francisco     NaN

# %%
## What was the average (mean) BasePay of all employees per year? (2011-2014)?

sal.groupby('Year')['BasePay'].mean()
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %%
## How many unique job titles are there? 

sal['JobTitle'].nunique()
# Out:
# 2159

# %%
## What are the top 5 most common jobs?

sal['JobTitle'].value_counts().head(5)
# Out:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: count, dtype: int64

# %%
## How many Job Titles were represented by only one person in 2013? 
## (e.g. Job Titles with only one occurence in 2013?)

sum(sal[sal['Year']== 2013]['JobTitle'].value_counts()== 1)
# Out:
# 202

# %%
## How many people have the word Chief in their job title? (This is pretty tricky)

def chief_string(title):
    if 'chief' in title.lower():
        return True
    else:
        return False

# %%
sum(sal['JobTitle'].apply(lambda x: chief_string(x)))
# Out:
# 627

# %%
# or #

sum(sal['JobTitle'].str.lower().str.contains('chief', na= False))
# Out:
# 627

# %%
## Is there a correlation between length of the Job Title string and Salary?

sal['title_len']= sal['JobTitle'].apply(len)

# %%
#چرا از [[]] استفاده می‌کنیم؟
# [] این فقط یک Series (ستون تکی) برمی‌گردونه.
# این یک DataFrame با دو ستون برمی‌گردونه (یعنی جدولی با هر دو ستون)
# cor() is only applicable for 2 column. 

sal[['title_len', 'TotalPayBenefits']].corr()

# No correlation
# Out:
#                   title_len  TotalPayBenefits
# title_len          1.000000         -0.036878
# TotalPayBenefits  -0.036878          1.000000

# %%
## non_null amount ##

sal['JobTitle'].count()
# Out:
# np.int64(148654)

# %%
## number of uniques  ##

sal['JobTitle'].nunique()
# Out:
# 2159

# %%
## how many time each unique variable is reapeted? ##

sal['JobTitle'].value_counts()
# Out:
# JobTitle
# Transit Operator                                  7036
# Special Nurse                                     4389
# Registered Nurse                                  3736
# Public Svc Aide-Public Works                      2518
# Police Officer 3                                  2421
#                                                   ...
# CHIEF HOUSING INSPECTOR                              1
# TRAFFIC SIGNAL OPERATOR                              1
# COURT COMPUTER FACILITIES COORDINATOR                1
# AUTOMOTIVE BODY AND FENDER WORKER SUPERVISOR I       1
# VICTIM & WITNESS TECHNICIAN                          1
# Name: count, Length: 2159, dtype: int64

# %%
## how many time each unique variable is reapeted? including none:  ##

sal['JobTitle'].value_counts(dropna=False)
# Out:
# JobTitle
# Transit Operator                                  7036
# Special Nurse                                     4389
# Registered Nurse                                  3736
# Public Svc Aide-Public Works                      2518
# Police Officer 3                                  2421
#                                                   ...
# CHIEF HOUSING INSPECTOR                              1
# TRAFFIC SIGNAL OPERATOR                              1
# COURT COMPUTER FACILITIES COORDINATOR                1
# AUTOMOTIVE BODY AND FENDER WORKER SUPERVISOR I       1
# VICTIM & WITNESS TECHNICIAN                          1
# Name: count, Length: 2159, dtype: int64

# %%
## first 3 most common jobs

sal['JobTitle'].value_counts().head(3)
# Out:
# JobTitle
# Transit Operator    7036
# Special Nurse       4389
# Registered Nurse    3736
# Name: count, dtype: int64

# %%
sal['BasePay'].mean()
# Out:
# np.float64(66325.44884048769)

# %%
sal['BasePay'].max()
# Out:
# np.float64(319275.01)

# %%
sal['BasePay'].min()
# Out:
# np.float64(-166.01)

# %%
sal = pd.read_csv('/Users/taherehehsan/Salaries.csv')

# %%
sal
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
type(sal)
# Out:
# pandas.core.frame.DataFrame

# %%
sal['EmployeeName']
# Out:
# 0            NATHANIEL FORD
# 1              GARY JIMENEZ
# 2            ALBERT PARDINI
# 3         CHRISTOPHER CHONG
# 4           PATRICK GARDNER
#                 ...
# 148649        Roy I Tillery
# 148650         Not provided
# 148651         Not provided
# 148652         Not provided
# 148653            Joe Lopez
# Name: EmployeeName, Length: 148654, dtype: object

# %%
type(sal['EmployeeName'])
# Out:
# pandas.core.series.Series
